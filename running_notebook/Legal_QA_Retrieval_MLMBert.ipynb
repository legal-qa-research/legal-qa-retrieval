# %% [markdown]
# # Pre-training BERT with MLM task

# %% [markdown]
# ## Setup enviroments

# %%
# !git clone https://github.com/legal-qa-research/legal-qa-retrieval.git
# Out:
# Cloning into 'legal-qa-retrieval'...
# remote: Enumerating objects: 462, done.
# remote: Counting objects: 100% (462/462), done.
# remote: Compressing objects: 100% (289/289), done.
# remote: Total 462 (delta 303), reused 318 (delta 159), pack-reused 0
# Receiving objects: 100% (462/462), 72.11 KiB | 10.30 MiB/s, done.
# Resolving deltas: 100% (303/303), done.

# %%
# %cd /content/legal-qa-retrieval
! git add .
! git reset --hard
! git pull origin master
# Out:
# /content/legal-qa-retrieval
# HEAD is now at 663abc0  add output dir arguments
# From https://github.com/legal-qa-research/legal-qa-retrieval
#  * branch            master     -> FETCH_HEAD
# Already up to date.

# %%
! nvidia-smi
# Out:
# Wed Apr  6 17:49:52 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   31C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
os.environ['PYTHONPATH'] += ":/content/legal-qa-retrieval"

# %%
# %%capture
! pip install -U gdown
! pip3 install transformers
! pip3 install datasets

# %% [markdown]
# ## Run training

# %%
# %cd /content/legal-qa-retrieval/
# %run /content/legal-qa-retrieval/legal_mlm_bert/bert_finetuner_mlm.py --corpus_path=/content/drive/Shareddrives/UnlimitedSharedDrive/legal_finetuned_data/bert_corpus_path_v1.txt --model_name=vinai/phobert-base --max_seq_length=128 --chk_path=/content/drive/Shareddrives/UnlimitedSharedDrive/mlm-fine-tuned-BERT-chkpoint-epoch2/checkpoint-100000 --output_dir=/content/drive/Shareddrives/UnlimitedSharedDrive/mlm-fine-tuned-BERT-chkpoint-epoch2
# Out:
# /content/legal-qa-retrieval
# Downloading:   0%|          | 0.00/557 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/874k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Downloading:   0%|          | 0.00/518M [00:00<?, ?B/s]
# Using custom data configuration default-4831d8dc24a2c0b6
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset text downloaded and prepared to /root/.cache/huggingface/datasets/text/default-4831d8dc24a2c0b6/0.0.0/4b86d314f7236db91f0a0f5cda32d4375445e64c5eda2692655dd99c2dac68e8. Subsequent calls will reuse this data.
# #0:   0%|          | 0/133 [00:00<?, ?ba/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (274 > 256). Running this sequence through the model will result in indexing errors
# #1:   0%|          | 0/133 [00:00<?, ?ba/s]
# ...
